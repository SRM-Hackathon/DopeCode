# %%
import json
import pandas as pd

# %%
file1 = '/home/pavan/DopeCode/mmtcfinal/home/static/FINALFLIGHTTEST.json'
file = '/home/pavan/DopeCode/mmtcfinal/home/static/FINALTRAINTEST.json'

# %%
with open(file) as train_file:
    dict_train = json.load(train_file)
# converting json dataset from dictionary to dataframe
train = pd.DataFrame.from_dict(dict_train, orient='columns')
train.reset_index(level=0, inplace=True)
with open(file1) as flight_file:
    dict_flight = json.load(flight_file)
flight = pd.DataFrame.from_dict(dict_flight, orient='columns')
flight.reset_index(level=0, inplace = True)

# %%
train.shape
# Out:
# (18687, 16)

# %% [raw]
# source = str(input("Enter source\n")).upper()
# destination = str(input("Enter destination\n")).upper()
#
# s = []
# for i in range(0,train.shape[0]):
#     b = []
#     if train.iloc[i,12] == source:
#         if train.iloc[i,7] == destination:
#             print(train.iloc[i,1:])
#             print('\n\n\n')
#             b.append(train.iloc[i,:])
#             s.append(b)
#
# g = []
# for i in range(0,flight.shape[0]):
#     b = []
#     if flight.iloc[i,7] == source:
#         if flight.iloc[i,10] == destination:
#             print(flight.iloc[i,1:])
#             print('\n\n\n')
#             b.append(flight.iloc[i,:])
#             g.append(b)

# %%
source = str(input("Enter source\n")).upper()
destination = str(input("Enter destination\n")).upper()

s = []lore
for i in range(0,train.shape[0]):
    b = []
    if train.iloc[i,12] == source:
        if train.iloc[i,7] == destination:
            print(train.iloc[i,1:])
            print('\n\n\n')
            b.append(train.iloc[i,:])
            s.append(b)
            
g = []
for i in range(0,flight.shape[0]):
    b = []
    if flight.iloc[i,7] == source:
        if flight.iloc[i,10] == destination:
            print(flight.iloc[i,1:])
            print('\n\n\n')
            b.append(flight.iloc[i,:])
            g.append(b)
# Out:
# Enter source
# tirupati
# Enter destination
# nellore
# 1A                          320
# 2A                          810
# 3A                          940
# Arrival time           20:00:00
# DAY                     1234567
# Dest Station Code           NLR
# Dest station_name       NELLORE
# Distance                    131
# SEQ                           3
# SL                          280
# Source Station             TPTY
# Source Station Name    TIRUPATI
# Train Name             VSKP HSP
# departure_time         20:02:00
# train_number               7044
# Name: 220, dtype: object
#
#
#
#
# 1A                          620
# 2A                          660
# 3A                         1040
# Arrival time           19:22:00
# DAY                           2
# Dest Station Code           NLR
# Dest station_name       NELLORE
# Distance                    131
# SEQ                           5
# SL                          200
# Source Station             TPTY
# Source Station Name    TIRUPATI
# Train Name             TPTY-KCG
# departure_time         19:23:00
# train_number               7146
# Name: 232, dtype: object
#
#
#
#
# 1A                              430
# 2A                              900
# 3A                             1090
# Arrival time                9:48:00
# DAY                         1234567
# Dest Station Code               NLR
# Dest station_name           NELLORE
# Distance                        131
# SEQ                               4
# SL                              270
# Source Station                 TPTY
# Source Station Name        TIRUPATI
# Train Name             TPTY-NSL HSP
# departure_time              9:50:00
# train_number                   7417
# Name: 274, dtype: object
#
#
#
#
# 1A                          350
# 2A                          650
# 3A                          990
# Arrival time           16:40:00
# DAY                     1234567
# Dest Station Code           NLR
# Dest station_name       NELLORE
# Distance                    131
# SEQ                           4
# SL                          240
# Source Station             TPTY
# Source Station Name    TIRUPATI
# Train Name              TPTY-SC
# departure_time         16:42:00
# train_number               7430
# Name: 306, dtype: object
#
#
#
#
# 1A                          570
# 2A                          880
# 3A                         1040
# Arrival time           19:21:00
# DAY                      123456
# Dest Station Code           NLR
# Dest station_name       NELLORE
# Distance                    131
# SEQ                           5
# SL                          220
# Source Station             TPTY
# Source Station Name    TIRUPATI
# Train Name             TPTY-CCT
# departure_time         19:23:00
# train_number               7432
# Name: 317, dtype: object
#
#
#
#
# 1A                           540
# 2A                           880
# 3A                           960
# Arrival time             0:40:00
# DAY                      1234567
# Dest Station Code            NLR
# Dest station_name        NELLORE
# Distance                     131
# SEQ                            3
# SL                           180
# Source Station              TPTY
# Source Station Name     TIRUPATI
# Train Name             TPTY-VSKP
# departure_time           0:42:00
# train_number                7487
# Name: 328, dtype: object
#
#
#
#
# 1A                          440
# 2A                          770
# 3A                         1050
# Arrival time           18:18:00
# DAY                     1234567
# Dest Station Code           NLR
# Dest station_name       NELLORE
# Distance                    131
# SEQ                           5
# SL                          120
# Source Station             TPTY
# Source Station Name    TIRUPATI
# Train Name             TPTY-NED
# departure_time         18:20:00
# train_number               7608
# Name: 340, dtype: object
#
#
#
#
# 1A                             560
# 2A                             820
# 3A                             960
# Arrival time              21:28:00
# DAY                        1234567
# Dest Station Code              NLR
# Dest station_name          NELLORE
# Distance                       131
# SEQ                              5
# SL                             300
# Source Station                TPTY
# Source Station Name       TIRUPATI
# Train Name             TPTY-COASPL
# departure_time            21:30:00
# train_number                  7942
# Name: 358, dtype: object
#
#
#
#
# 1A                              320
# 2A                              880
# 3A                              970
# Arrival time               18:00:00
# DAY                         1234567
# Dest Station Code               NLR
# Dest station_name           NELLORE
# Distance                        131
# SEQ                               5
# SL                              140
# Source Station                 TPTY
# Source Station Name        TIRUPATI
# Train Name             TPTY-VSKP SP
# departure_time             18:02:00
# train_number                   8574
# Name: 435, dtype: object
#
#
#
#
# 1A                              540
# 2A                              690
# 3A                             1050
# Arrival time               20:42:00
# DAY                         1234567
# Dest Station Code               NLR
# Dest station_name           NELLORE
# Distance                        131
# SEQ                               6
# SL                              160
# Source Station                 TPTY
# Source Station Name        TIRUPATI
# Train Name             TPTY-SC NARA
# departure_time             20:44:00
# train_number                  12733
# Name: 3254, dtype: object
#
#
#
#
# 1A                              520
# 2A                              670
# 3A                              970
# Arrival time               19:22:00
# DAY                         1234567
# Dest Station Code               NLR
# Dest station_name           NELLORE
# Distance                        131
# SEQ                               6
# SL                              110
# Source Station                 TPTY
# Source Station Name        TIRUPATI
# Train Name             TPTY-SC PADM
# departure_time             19:23:00
# train_number                  12763
# Name: 3333, dtype: object
#
#
#
#
# 1A                             580
# 2A                             670
# 3A                             970
# Arrival time              22:04:00
# DAY                        1234567
# Dest Station Code              NLR
# Dest station_name          NELLORE
# Distance                       131
# SEQ                              7
# SL                             110
# Source Station                TPTY
# Source Station Name       TIRUPATI
# Train Name             TPTY-MTM NS
# departure_time            22:06:00
# train_number                 17401
# Name: 6736, dtype: object
#
#
#
#
# 1A                              590
# 2A                              900
# 3A                             1000
# Arrival time                8:09:00
# DAY                           12567
# Dest Station Code               NLR
# Dest station_name           NELLORE
# Distance                        131
# SEQ                               8
# SL                              130
# Source Station                 TPTY
# Source Station Name        TIRUPATI
# Train Name             TPTY-ADB KRI
# departure_time              8:11:00
# train_number                  17405
# Name: 6757, dtype: object
#
#
#
#
# 1A                              530
# 2A                              760
# 3A                              910
# Arrival time               13:30:00
# DAY                         1234567
# Dest Station Code               NLR
# Dest station_name           NELLORE
# Distance                        131
# SEQ                               7
# SL                              290
# Source Station                 TPTY
# Source Station Name        TIRUPATI
# Train Name             TPTY-PURI EX
# departure_time             13:32:00
# train_number                  17480
# Name: 6989, dtype: object
#
#
#
#
# 1A                              560
# 2A                              740
# 3A                             1000
# Arrival time               13:31:00
# DAY                              17
# Dest Station Code               NLR
# Dest station_name           NELLORE
# Distance                        131
# SEQ                               7
# SL                              290
# Source Station                 TPTY
# Source Station Name        TIRUPATI
# Train Name             TPTY-BSP EXP
# departure_time             13:32:00
# train_number                  17482
# Name: 7061, dtype: object
#
#
#
#
# 1A                              570
# 2A                              710
# 3A                             1070
# Arrival time               23:08:00
# DAY                         1234567
# Dest Station Code               NLR
# Dest station_name           NELLORE
# Distance                        131
# SEQ                               7
# SL                              160
# Source Station                 TPTY
# Source Station Name        TIRUPATI
# Train Name             TPTY-VSKP TI
# departure_time             23:10:00
# train_number                  17487
# Name: 7126, dtype: object
#
#
#
#
# 1A                              350
# 2A                              740
# 3A                             1000
# Arrival time                0:18:00
# DAY                               2
# Dest Station Code               NLR
# Dest station_name           NELLORE
# Distance                        131
# SEQ                               5
# SL                              300
# Source Station                 TPTY
# Source Station Name        TIRUPATI
# Train Name             TPTY-VSKP TR
# departure_time              0:20:00
# train_number                  22708
# Name: 9215, dtype: object
#
#
#
#
# 1A                              480
# 2A                              890
# 3A                             1100
# Arrival time               15:17:00
# DAY                          134567
# Dest Station Code               NLR
# Dest station_name           NELLORE
# Distance                        131
# SEQ                               3
# SL                              190
# Source Station                 TPTY
# Source Station Name        TIRUPATI
# Train Name             TPTY-BBS S/F
# departure_time             15:18:00
# train_number                  22872
# Name: 9480, dtype: object
#
#
#
#
# 1A                              440
# 2A                              770
# 3A                              980
# Arrival time               15:17:00
# DAY                         1234567
# Dest Station Code               NLR
# Dest station_name           NELLORE
# Distance                        131
# SEQ                               4
# SL                              160
# Source Station                 TPTY
# Source Station Name        TIRUPATI
# Train Name             TPTY-BBS S/F
# departure_time             15:18:00
# train_number                  22880
# Name: 9514, dtype: object
# 1A                              410
# 2A                              670
# 3A                              960
# Arrival time                4:44:00
# DAY                               2
# Dest Station Code               NLR
# Dest station_name           NELLORE
# Distance                        131
# SEQ                              15
# SL                              280
# Source Station                 TPTY
# Source Station Name        TIRUPATI
# Train Name             TPTY-COA PAS
# departure_time              4:46:00
# train_number                  57257
# Name: 15161, dtype: object
#
#
#
#
# 1A                          630
# 2A                          850
# 3A                          950
# Arrival time           18:00:00
# DAY                     1234567
# Dest Station Code           NLR
# Dest station_name       NELLORE
# Distance                    131
# SEQ                          16
# SL                          140
# Source Station             TPTY
# Source Station Name    TIRUPATI
# Train Name                 PASS
# departure_time         18:02:00
# train_number              57329
# Name: 15312, dtype: object
#
#
#
#
# 1A                              390
# 2A                              720
# 3A                             1040
# Arrival time               14:50:00
# DAY                         1234567
# Dest Station Code               NLR
# Dest station_name           NELLORE
# Distance                        131
# SEQ                              16
# SL                              250
# Source Station                 TPTY
# Source Station Name        TIRUPATI
# Train Name             TPTY-NLR PAS
# departure_time             14:50:00
# train_number                  66033
# Name: 17555, dtype: object

# %%
for i in s:
    print(type(i))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
r = pd.DataFrame()
for i in s:
    r2 = pd.DataFrame(i)
    r = pd.concat([r,r2], axis = 0)

# %%
o = []
for i in range(0,len(r)):
    p = []
    p = list(r.iloc[i,:])
    o.append(p)

# %%
r
# Out:
#        index   1A   2A    3A Arrival time      DAY Dest Station Code  \
# 220      220  320  810   940     20:00:00  1234567               NLR
# 232      232  620  660  1040     19:22:00        2               NLR
# 274      274  430  900  1090      9:48:00  1234567               NLR
# 306      306  350  650   990     16:40:00  1234567               NLR
# 317      317  570  880  1040     19:21:00   123456               NLR
# 328      328  540  880   960      0:40:00  1234567               NLR
# 340      340  440  770  1050     18:18:00  1234567               NLR
# 358      358  560  820   960     21:28:00  1234567               NLR
# 435      435  320  880   970     18:00:00  1234567               NLR
# 3254    3254  540  690  1050     20:42:00  1234567               NLR
# 3333    3333  520  670   970     19:22:00  1234567               NLR
# 6736    6736  580  670   970     22:04:00  1234567               NLR
# 6757    6757  590  900  1000      8:09:00    12567               NLR
# 6989    6989  530  760   910     13:30:00  1234567               NLR
# 7061    7061  560  740  1000     13:31:00       17               NLR
# 7126    7126  570  710  1070     23:08:00  1234567               NLR
# 9215    9215  350  740  1000      0:18:00        2               NLR
# 9480    9480  480  890  1100     15:17:00   134567               NLR
# 9514    9514  440  770   980     15:17:00  1234567               NLR
# 15161  15161  410  670   960      4:44:00        2               NLR
# 15312  15312  630  850   950     18:00:00  1234567               NLR
# 17555  17555  390  720  1040     14:50:00  1234567               NLR
#
#       Dest station_name  Distance  SEQ   SL Source Station  \
# 220             NELLORE       131    3  280           TPTY
# 232             NELLORE       131    5  200           TPTY
# 274             NELLORE       131    4  270           TPTY
# 306             NELLORE       131    4  240           TPTY
# 317             NELLORE       131    5  220           TPTY
# 328             NELLORE       131    3  180           TPTY
# 340             NELLORE       131    5  120           TPTY
# 358             NELLORE       131    5  300           TPTY
# 435             NELLORE       131    5  140           TPTY
# 3254            NELLORE       131    6  160           TPTY
# 3333            NELLORE       131    6  110           TPTY
# 6736            NELLORE       131    7  110           TPTY
# 6757            NELLORE       131    8  130           TPTY
# 6989            NELLORE       131    7  290           TPTY
# 7061            NELLORE       131    7  290           TPTY
# 7126            NELLORE       131    7  160           TPTY
# 9215            NELLORE       131    5  300           TPTY
# 9480            NELLORE       131    3  190           TPTY
# 9514            NELLORE       131    4  160           TPTY
# 15161           NELLORE       131   15  280           TPTY
# 15312           NELLORE       131   16  140           TPTY
# 17555           NELLORE       131   16  250           TPTY
#
#       Source Station Name    Train Name departure_time  train_number
# 220              TIRUPATI      VSKP HSP       20:02:00          7044
# 232              TIRUPATI      TPTY-KCG       19:23:00          7146
# 274              TIRUPATI  TPTY-NSL HSP        9:50:00          7417
# 306              TIRUPATI       TPTY-SC       16:42:00          7430
# 317              TIRUPATI      TPTY-CCT       19:23:00          7432
# 328              TIRUPATI     TPTY-VSKP        0:42:00          7487
# 340              TIRUPATI      TPTY-NED       18:20:00          7608
# 358              TIRUPATI   TPTY-COASPL       21:30:00          7942
# 435              TIRUPATI  TPTY-VSKP SP       18:02:00          8574
# 3254             TIRUPATI  TPTY-SC NARA       20:44:00         12733
# 3333             TIRUPATI  TPTY-SC PADM       19:23:00         12763
# 6736             TIRUPATI   TPTY-MTM NS       22:06:00         17401
# 6757             TIRUPATI  TPTY-ADB KRI        8:11:00         17405
# 6989             TIRUPATI  TPTY-PURI EX       13:32:00         17480
# 7061             TIRUPATI  TPTY-BSP EXP       13:32:00         17482
# 7126             TIRUPATI  TPTY-VSKP TI       23:10:00         17487
# 9215             TIRUPATI  TPTY-VSKP TR        0:20:00         22708
# 9480             TIRUPATI  TPTY-BBS S/F       15:18:00         22872
# 9514             TIRUPATI  TPTY-BBS S/F       15:18:00         22880
# 15161            TIRUPATI  TPTY-COA PAS        4:46:00         57257
# 15312            TIRUPATI          PASS       18:02:00         57329
# 17555            TIRUPATI  TPTY-NLR PAS       14:50:00         66033

# %%
k.iloc[0,:]
# Out:
# index                         17555
# 1A                              390
# 2A                              720
# 3A                             1040
# Arrival time               14:50:00
# DAY                         1234567
# Dest Station Code               NLR
# Dest station_name           NELLORE
# Distance                        131
# SEQ                              16
# SL                              250
# Source Station                 TPTY
# Source Station Name        TIRUPATI
# Train Name             TPTY-NLR PAS
# departure_time             14:50:00
# train_number                  66033
# Name: 17555, dtype: object
